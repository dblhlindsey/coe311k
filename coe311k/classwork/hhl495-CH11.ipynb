# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

# %%
#Polynomial Fitting
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(x_interp)
# Out:
# Polynomial Coefficients:  [ 0.07407407 -0.55555556  1.1005291   0.06349206]

# %%
plt.plot(x_interp, y_pred, label = "Polyfit Curve")
plt.plot(x_interp, y_interp, label = "Cubic Spline Curve")
plt.scatter(x,y)
plt.title("Cubic Spline vs Polynomial Fit")
plt.legend()
plt.show()

# %%
#The curves differ greatly, as shown the cubic spline curve is able to pass through all 6 of the points and display
#an oscillating function, a wave. The cubic spline is better for this set of data but is likely prone to overfitting when
#handling data sets with more variance and entries.
