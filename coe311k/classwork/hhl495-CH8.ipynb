# %%
import numpy as np

def diagonalDominance(array):
    strength = "Strictly Dominant"
    for i in range(len(array)):
        sum = 0
        for j in range(len(array)):
            if (j != i):
                sum += abs(array[i,j])
        if (abs(array[i,i]) < sum):
            return "Not Diagonally Dominant"
        if  (array[i,i] == sum):
            strength = "Weakly Dominant"
    return strength

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

B = np.array([[0, 4, 4],
              [4, 2, 3],
              [2, 9, 1]])

C = np.array([[1, 1], [1, 1.0001]])

print("Matrix A Diagonal Dominance:")
print(diagonalDominance(A))
print("\n")

print("Matrix B Diagonal Dominance:")
print(diagonalDominance(B))
print("\n")

print("Matrix C Diagonal Dominance:")
print(diagonalDominance(C))
print("\n")
# Out:
# Matrix A Diagonal Dominance:
# Strictly Dominant
#
#
# Matrix B Diagonal Dominance:
# Not Diagonally Dominant
#
#
# Matrix C Diagonal Dominance:
# Weakly Dominant
